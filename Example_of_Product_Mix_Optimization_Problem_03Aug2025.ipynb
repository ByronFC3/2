# %% [markdown]
# <a href="https://colab.research.google.com/github/ByronFC3/2/blob/main/Example_of_Product_Mix_Optimization_Problem_03Aug2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example: Product Mix Optimization
# Problem Statement:
# A factory makes two products: Widgets and Gadgets. Each product requires time on two machines:
#
# Machine A (hours)	Machine B (hours)	Profit per unit
# Widget	2	1	$30
# Gadget	1	2	$20
#
# You have:
#
# 100 hours available on Machine A
#
# 80 hours available on Machine B
#
# You want to determine how many Widgets (x) and Gadgets (y) to produce in order to maximize profit.
#
# 📐 Step 1: Define Decision Variables
# Let x = number of Widgets to produce
#
# Let y = number of Gadgets to produce
#
# 📉 Step 2: Formulate the Constraints
# Machine A time constraint:
# 2x + 1y ≤ 100
#
# Machine B time constraint:
# 1x + 2y ≤ 80
#
# Non-negativity constraints:
# x ≥ 0, y ≥ 0
#
# 💰 Step 3: Define the Objective Function
# Maximize total profit:
# Maximize Z = 30x + 20y
#
# 🧠 Final Linear Program:
# Maximize
#   Z = 30x + 20y
#
# Subject to
#   2x + y ≤ 100
#    x + 2y ≤ 80
#   x ≥ 0, y ≥ 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Create x values
x = np.linspace(0, 60, 400)

# Constraint lines
y1 = 100 - 2*x         # From 2x + y = 100
y2 = (80 - x) / 2      # From x + 2y = 80

# Plot constraint lines
ax.plot(x, y1, label='2x + y ≤ 100')
ax.plot(x, y2, label='x + 2y ≤ 80')

# Fill feasible region
y1_clip = np.minimum(y1, y2)
y1_clip = np.maximum(y1_clip, 0)
ax.fill_between(x, 0, y1_clip, where=(y1_clip > 0), color='lightblue', alpha=0.5, label='Feasible Region')

# Plot corner points
points = {
    "A (0, 0)": (0, 0),
    "B (50, 0)": (50, 0),
    "C (40, 20)": (40, 20),
    "D (0, 40)": (0, 40)
}
for label, (px, py) in points.items():
    ax.plot(px, py, 'ro')
    ax.text(px + 1, py + 1, label, fontsize=9)

# Labels and title
ax.set_xlim(0, 60)
ax.set_ylim(0, 60)
ax.set_xlabel('Widgets (x)')
ax.set_ylabel('Gadgets (y)')
ax.set_title('Feasible Region and Constraint Lines')
ax.legend()
ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# The plot showing the feasible region (shaded in blue), the constraint lines, and the corner points labeled. The optimal solution occurs at point C (40, 20), which gives the maximum profit of $1,600. Let me know if you'd like the solution steps overlaid on the graph or exported as a file.
