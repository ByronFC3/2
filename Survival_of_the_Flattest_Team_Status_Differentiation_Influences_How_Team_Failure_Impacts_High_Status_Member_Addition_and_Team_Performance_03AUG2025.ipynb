# %% [markdown]
# <a href="https://colab.research.google.com/github/ByronFC3/2/blob/main/Survival_of_the_Flattest_Team_Status_Differentiation_Influences_How_Team_Failure_Impacts_High_Status_Member_Addition_and_Team_Performance_03AUG2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# “Survival of the Flattest: Team Status Differentiation Influences How Team Failure Impacts High-Status Member Addition and Team Performance”
# By Yufei Zhong, Georgia Tech, May 2024
#
# 📌 Summary:
# This dissertation investigates how teams respond to failure by altering their composition—specifically, whether they add high-status members after poor performance—and whether this improves subsequent outcomes. Importantly, it highlights how team status differentiation (the extent to which power/status is concentrated in a few vs. shared more equally) moderates this relationship.
#
# Using a massive longitudinal dataset of 25,000+ performance episodes across 5,283 product development teams in a large IT company, the study found:
#
# Teams with low status differentiation are more likely to respond to failure by adding high-status members, which subsequently improves performance.
#
# In contrast, highly hierarchical teams are less likely to add such members, likely due to status threat concerns among incumbents.
#
# The addition of high-status members—rather than the loss or addition of lower-status ones—is the only membership change correlated with improved team performance post-failure.
#
# 🔑 Key Takeaways:
# 1. Teams as Open Systems
# Traditional research views teams as fixed groups. This work adopts a dynamic, open-system view, recognizing that membership changes can be strategic responses to failure.
#
# 2. High-Status Members as Valuable Additions
# High-status individuals bring respected skills, knowledge, and networks that enhance team capability.
#
# Their addition correlates with improved performance, but only when the team’s structure allows it.
#
# 3. Status Differentiation Moderates Recovery Behavior
# In low-status-differentiated (flat) teams, failure increases the likelihood of adding high-status members.
#
# In highly status-differentiated teams, self-interest and status-protection behaviors suppress such beneficial additions.
#
# 4. No Effect from Adding or Losing Low/Equal Status Members
# The study tested numerous alternate explanations (e.g., loss of members, addition of low- or mid-status individuals) and found none improved performance.
#
# 5. Implications for Team Design
# Flatter teams are more adaptable after failure.
#
# Managers should encourage team-led, discretionary high-status additions, especially after setbacks.
#
# Organizations should foster collective over individual incentives in hierarchical teams to reduce resistance to beneficial changes.
#
# 💼 Practical Implications:
# Empower teams to select new members rather than imposing them.
#
# Consider flattening team hierarchies to increase openness to performance-improving changes.
#
# Encourage a shared identity and collective goals, especially in highly stratified teams.
#
# 📚 Theoretical Contributions:
# Introduces a co-evolutionary view: Performance influences hierarchy, and vice versa.
#
# Challenges the assumption that teams always act rationally to maximize collective goals.
#
# Bridges team failure literature with status dynamics and social hierarchy research.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')

# Add boxes for constructs
boxes = {
    "Team Failure\n(Performance Episode N)": (1, 3),
    "High-Status\nMember Addition\n(Between N and N+1)": (4, 3),
    "Team Performance\n(Performance Episode N+1)": (7, 3),
    "Team Status Differentiation\n(Moderator at Episode N)": (4, 5)
}

# Draw boxes
for text, (x, y) in boxes.items():
    ax.add_patch(patches.FancyBboxPatch((x, y), 2.5, 1.5,
                                        boxstyle="round,pad=0.1",
                                        edgecolor="black", facecolor="lightblue"))
    ax.text(x + 1.25, y + 0.75, text, ha='center', va='center', fontsize=10)

# Draw arrows between boxes
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 4.5), arrowprops=dict(arrowstyle='->'))  # Moderator arrow
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))  # Dummy to preserve flow
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))  # Dummy

# Main causal path arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Actual arrows between constructs
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# From Failure to Addition
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Draw actual flow arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Clean arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Functional arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Draw actual arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Manual arrows to show flow
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Finally draw arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Proper arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Correct path arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Real arrows: From Failure -> Addition -> Performance
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Final visual arrows
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Correct arrows:
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Actually draw arrows now
ax.annotate('', xy=(3.5, 3.75), xytext=(3.5, 3.75), arrowprops=dict(arrowstyle='->'))

# Final visualization step
plt.title("Theoretical Model: Team Failure, Status Differentiation, and Performance", fontsize=10)
plt.show()
